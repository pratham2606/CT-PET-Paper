# %%
# ============================================================
# GOOGLE COLAB / T4 ENVIRONMENT
# No TensorFlow/Keras downgrade and NO tensorflow-addons.
# This avoids the Python 3.13 / TensorFlow Addons installation error.
# ============================================================
import sys
import subprocess

print("Python:", sys.version)

# KaggleHub is used only to download the public dataset in Colab.
try:
    import kagglehub
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "kagglehub"])
    import kagglehub

import tensorflow as tf
print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))
# Out:
# Python: 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]
# TensorFlow: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
import random
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import skimage.io

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization,
    Activation, GlobalAveragePooling2D, DepthwiseConv2D, Input, Add, Concatenate,
    ReLU, LeakyReLU
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (
    ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
)
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow:", tf.__version__)
print("Keras:", keras.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow: 2.20.0
# Keras: 3.13.2
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# TensorFlow Addons is intentionally NOT used.
# The original notebook used tfa.metrics.F1Score; it is replaced below
# by a native tf.keras metric so the notebook works on current Colab Python.
print("TensorFlow Addons dependency removed.")
# Out:
# TensorFlow Addons dependency removed.

# %%
# ============================================================
# DATASET LOADING — FINAL 4-CLASS 60/20/20 SPLIT
# ============================================================
# The Kaggle dataset contains 7 source folders, which are merged
# into the 4 final ML classes below.
#
# FINAL CLASSES:
#   adenocarcinoma
#   large.cell.carcinoma
#   normal
#   squamous.cell.carcinoma
#
# ALL images from original train/test/valid are combined first,
# then shuffled and stratified into 60% train / 20% validation /
# 20% test.
# ============================================================

import os
import random
import shutil
from pathlib import Path
from sklearn.model_selection import train_test_split

RANDOM_STATE = 42
random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)

# Download dataset
DATASET_DOWNLOAD_PATH = None
if DATASET_DOWNLOAD_PATH is None:
    import kagglehub
    DATASET_DOWNLOAD_PATH = kagglehub.dataset_download(
        "mohamedhanyyy/chest-ctscan-images"
    )

print("Downloaded dataset location:", DATASET_DOWNLOAD_PATH)

def find_dataset_split_root(root):
    root = Path(root)
    candidates = [root] + [p for p in root.rglob("*") if p.is_dir()]
    for p in candidates:
        names = {x.name.lower() for x in p.iterdir() if x.is_dir()}
        if {"train", "test", "valid"}.issubset(names):
            return p
    raise FileNotFoundError(
        f"Could not find train/, test/, and valid/ inside {root}."
    )

source_root = find_dataset_split_root(DATASET_DOWNLOAD_PATH)

original_train_dir = source_root / "train"
original_test_dir = source_root / "test"
original_valid_dir = source_root / "valid"

# ------------------------------------------------------------
# Explicit 7-source-folder -> 4-final-class mapping
# ------------------------------------------------------------
CLASS_MAP = {
    "adenocarcinoma":
        "adenocarcinoma",
    "adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib":
        "adenocarcinoma",

    "large.cell.carcinoma":
        "large.cell.carcinoma",
    "large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa":
        "large.cell.carcinoma",

    "normal":
        "normal",

    "squamous.cell.carcinoma":
        "squamous.cell.carcinoma",
    "squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa":
        "squamous.cell.carcinoma",
}

# IMPORTANT:
# This order is also supplied explicitly to flow_from_directory()
# so train/validation/test all use exactly the same label indices.
class_names = [
    "adenocarcinoma",
    "large.cell.carcinoma",
    "normal",
    "squamous.cell.carcinoma",
]

NUM_CLASSES = len(class_names)

print("\nSource root:", source_root)
print("\nFinal 4 classes:")
for i, name in enumerate(class_names):
    print(f"  {i}: {name}")

# ------------------------------------------------------------
# Collect ALL images from original train/test/valid
# ------------------------------------------------------------
valid_ext = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"}

all_images = []

for split_dir in [
    original_train_dir,
    original_test_dir,
    original_valid_dir
]:
    for source_class_dir in split_dir.iterdir():

        if not source_class_dir.is_dir():
            continue

        source_class = source_class_dir.name

        if source_class not in CLASS_MAP:
            raise ValueError(
                f"Unexpected source class folder: {source_class}"
            )

        final_class = CLASS_MAP[source_class]

        for file_path in source_class_dir.iterdir():
            if (
                file_path.is_file()
                and file_path.suffix.lower() in valid_ext
            ):
                all_images.append(
                    (
                        str(file_path),
                        final_class,
                        source_class
                    )
                )

if not all_images:
    raise RuntimeError("No image files were found.")

# ------------------------------------------------------------
# Shuffle and stratified 60/20/20 split
# ------------------------------------------------------------
random.shuffle(all_images)

labels = [
    final_class
    for _, final_class, _ in all_images
]

train_data, temp_data = train_test_split(
    all_images,
    test_size=0.40,
    random_state=RANDOM_STATE,
    shuffle=True,
    stratify=labels
)

temp_labels = [
    final_class
    for _, final_class, _ in temp_data
]

valid_data, test_data = train_test_split(
    temp_data,
    test_size=0.50,
    random_state=RANDOM_STATE,
    shuffle=True,
    stratify=temp_labels
)

print("\n" + "=" * 70)
print("FINAL 60/20/20 SPLIT")
print("=" * 70)
print(f"Total : {len(all_images)}")
print(f"Train : {len(train_data)} ({len(train_data)/len(all_images)*100:.2f}%)")
print(f"Valid : {len(valid_data)} ({len(valid_data)/len(all_images)*100:.2f}%)")
print(f"Test  : {len(test_data)} ({len(test_data)/len(all_images)*100:.2f}%)")

# ------------------------------------------------------------
# Create clean 4-class directories
# ------------------------------------------------------------
base_dir = Path("/content/ct-scan-60-20-20")

if base_dir.exists():
    shutil.rmtree(base_dir)

train_dir = base_dir / "train"
valid_dir = base_dir / "valid"
test_dir = base_dir / "test"

for split_dir in [train_dir, valid_dir, test_dir]:
    for class_name in class_names:
        (split_dir / class_name).mkdir(
            parents=True,
            exist_ok=True
        )

# ------------------------------------------------------------
# Copy images
# Prefix source folder to avoid filename collisions
# ------------------------------------------------------------
def copy_images(data, destination_dir):

    for source_path, final_class, source_class in data:

        source_path = Path(source_path)

        safe_source = (
            source_class
            .replace("/", "_")
            .replace("\\", "_")
        )

        destination_name = (
            f"{safe_source}__{source_path.name}"
        )

        destination_path = (
            destination_dir
            / final_class
            / destination_name
        )

        shutil.copy2(
            source_path,
            destination_path
        )

copy_images(train_data, train_dir)
copy_images(valid_data, valid_dir)
copy_images(test_data, test_dir)

# ------------------------------------------------------------
# Final directory verification
# ------------------------------------------------------------
for split_name, split_dir in [
    ("TRAIN", train_dir),
    ("VALIDATION", valid_dir),
    ("TEST", test_dir),
]:

    detected = sorted([
        p.name
        for p in split_dir.iterdir()
        if p.is_dir()
    ])

    if detected != sorted(class_names):
        raise ValueError(
            f"{split_name} has incorrect classes.\n"
            f"Expected: {sorted(class_names)}\n"
            f"Found: {detected}"
        )

    print(
        f"{split_name}: verified 4 classes -> {detected}"
    )

print("\n" + "=" * 70)
print("4-CLASS DATASET CREATED SUCCESSFULLY")
print("=" * 70)
# Out:
# Using Colab cache for faster access to the 'chest-ctscan-images' dataset.
# Downloaded dataset location: /kaggle/input/chest-ctscan-images
#
# Source root: /kaggle/input/chest-ctscan-images/Data
#
# Final 4 classes:
#   0: adenocarcinoma
#   1: large.cell.carcinoma
#   2: normal
#   3: squamous.cell.carcinoma
#
# ======================================================================
# FINAL 60/20/20 SPLIT
# ======================================================================
# Total : 1000
# Train : 600 (60.00%)
# Valid : 200 (20.00%)
# Test  : 200 (20.00%)
# TRAIN: verified 4 classes -> ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma']
# VALIDATION: verified 4 classes -> ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma']
# TEST: verified 4 classes -> ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma']
#
# ======================================================================
# 4-CLASS DATASET CREATED SUCCESSFULLY
# ======================================================================

# %%
train_datagen = ImageDataGenerator(
    # rescale=1.0/255,
    # rotation_range=20,
    # width_shift_range=0.2,
    # height_shift_range=0.2,
    # shear_range=0.2,
    # zoom_range=0.2,
    # horizontal_flip=True
)

# %%
valid_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()

# %%
# ============================================================
# TRAIN GENERATOR — 4 CLASSES ONLY
# ============================================================

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode="categorical",
    classes=class_names,
    shuffle=True,
    seed=RANDOM_STATE
)

print("Train class_indices:", train_generator.class_indices)
# Out:
# Found 579 images belonging to 4 classes.
# Train class_indices: {'adenocarcinoma': 0, 'large.cell.carcinoma': 1, 'normal': 2, 'squamous.cell.carcinoma': 3}

# %%
# ============================================================
# VALIDATION GENERATOR — 4 CLASSES ONLY
# ============================================================

validation_generator = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode="categorical",
    classes=class_names,
    shuffle=False
)

print("Validation class_indices:", validation_generator.class_indices)
# Out:
# Found 200 images belonging to 4 classes.
# Validation class_indices: {'adenocarcinoma': 0, 'large.cell.carcinoma': 1, 'normal': 2, 'squamous.cell.carcinoma': 3}

# %%
# ============================================================
# TEST GENERATOR — 4 CLASSES ONLY
# ============================================================

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode="categorical",
    classes=class_names,
    shuffle=False
)

print("Test class_indices:", test_generator.class_indices)
# Out:
# Found 196 images belonging to 4 classes.
# Test class_indices: {'adenocarcinoma': 0, 'large.cell.carcinoma': 1, 'normal': 2, 'squamous.cell.carcinoma': 3}

# %%
# ============================================================
# FINAL 4-CLASS GENERATOR CHECK
# ============================================================

expected_num_classes = 4

for generator_name, generator in [
    ("train_generator", train_generator),
    ("validation_generator", validation_generator),
    ("test_generator", test_generator),
]:
    if generator.num_classes != expected_num_classes:
        raise ValueError(
            f"{generator_name} has {generator.num_classes} classes; "
            f"expected exactly {expected_num_classes}."
        )

    actual_order = [
        name
        for name, index in sorted(
            generator.class_indices.items(),
            key=lambda item: item[1]
        )
    ]

    if actual_order != class_names:
        raise ValueError(
            f"{generator_name} class order mismatch.\n"
            f"Expected: {class_names}\n"
            f"Got: {actual_order}"
        )

print("=" * 70)
print("SUCCESS: ALL GENERATORS USE EXACTLY 4 CLASSES")
print("=" * 70)
print("Class mapping:")
for i, name in enumerate(class_names):
    print(f"  {i}: {name}")
print("=" * 70)
# Out:
# ======================================================================
# SUCCESS: ALL GENERATORS USE EXACTLY 4 CLASSES
# ======================================================================
# Class mapping:
#   0: adenocarcinoma
#   1: large.cell.carcinoma
#   2: normal
#   3: squamous.cell.carcinoma
# ======================================================================

# %%
# Example to list files in the test directory
test_files = os.listdir(test_dir)
print("Number of files in test directory:", len(test_files))
# Out:
# Number of files in test directory: 4

# %%
print("Test directory:", test_dir)
# Out:
# Test directory: /content/ct-scan-60-20-20/test

# %%
# Native Keras-compatible F1 function (kept for compatibility with the original notebook).
def f1_score(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.round(tf.clip_by_value(y_pred, 0.0, 1.0))
    true_positives = tf.reduce_sum(y_true * y_pred)
    possible_positives = tf.reduce_sum(y_true)
    predicted_positives = tf.reduce_sum(y_pred)
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    return 2.0 * precision * recall / (precision + recall + K.epsilon())

# %%
# ============================================================
# NATIVE MICRO-F1 METRIC
# Replaces tfa.metrics.F1Score(num_classes=4, average="micro").
# ============================================================
class MicroF1(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = int(num_classes)
        self.tp = self.add_weight(name="tp", initializer="zeros")
        self.fp = self.add_weight(name="fp", initializer="zeros")
        self.fn = self.add_weight(name="fn", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.argmax(y_true, axis=-1)
        y_pred = tf.argmax(y_pred, axis=-1)
        y_true = tf.cast(y_true, tf.int32)
        y_pred = tf.cast(y_pred, tf.int32)

        cm = tf.math.confusion_matrix(
            y_true, y_pred, num_classes=self.num_classes, dtype=tf.float32
        )
        tp = tf.reduce_sum(tf.linalg.diag_part(cm))
        fp = tf.reduce_sum(cm, axis=0) - tf.linalg.diag_part(cm)
        fn = tf.reduce_sum(cm, axis=1) - tf.linalg.diag_part(cm)
        self.tp.assign_add(tp)
        self.fp.assign_add(tf.reduce_sum(fp))
        self.fn.assign_add(tf.reduce_sum(fn))

    def result(self):
        precision = self.tp / (self.tp + self.fp + K.epsilon())
        recall = self.tp / (self.tp + self.fn + K.epsilon())
        return 2.0 * precision * recall / (precision + recall + K.epsilon())

    def reset_state(self):
        for v in self.variables:
            v.assign(0.0)

METRICS = [
    tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    tf.keras.metrics.AUC(name="auc", multi_label=True, num_labels=4),
    MicroF1(num_classes=4, name="f1_score")
]

# %%
# ============================================================
# EXPERIMENT 2
# Remove ALL DWSC / DepthwiseConv2D layers from MAIN branch
# Keep DWSC layers in the SAM / PARALLEL branch unchanged.
#
# Also preserves the previous experiment:
# - Both 1x1 convolution layers are removed.
#
# IMPORTANT SHAPE FIX:
# Block 4 starts from block3_output (28x28x96), not from x
# (56x56x64). This makes the skip concatenation valid.
# ============================================================

from tensorflow.keras.layers import (
    Input,
    Conv2D,
    DepthwiseConv2D,
    BatchNormalization,
    MaxPooling2D,
    GlobalAveragePooling2D,
    Concatenate,
    Dense,
    ReLU
)
from tensorflow.keras.models import Model


# ============================================================
# INPUT
# ============================================================

input_layer = Input(
    shape=(224, 224, 3),
    name="input"
)


# ============================================================
# BLOCK 1
# ============================================================

x = Conv2D(
    32,
    (3, 3),
    activation="relu",
    padding="same",
    name="block1_conv"
)(input_layer)

x = BatchNormalization(
    name="block1_bn"
)(x)

x = MaxPooling2D(
    (2, 2),
    name="block1_pool"
)(x)


# ============================================================
# BLOCK 2
# ============================================================

x = Conv2D(
    64,
    (3, 3),
    activation="relu",
    padding="same",
    name="block2_conv"
)(x)

x = BatchNormalization(
    name="block2_bn"
)(x)

x = MaxPooling2D(
    (2, 2),
    name="block2_pool"
)(x)


# ============================================================
# BLOCK 3
# ============================================================

block3_output = Conv2D(
    96,
    (3, 3),
    activation="relu",
    padding="same",
    name="block3_conv"
)(x)

block3_output = BatchNormalization(
    name="block3_bn"
)(block3_output)

block3_output = MaxPooling2D(
    (2, 2),
    name="block3_pool"
)(block3_output)


# ============================================================
# BLOCK 4 — MAIN BRANCH
#
# EXPERIMENT 2:
# ALL DWSC / DepthwiseConv2D layers removed from main branch.
#
# Previous 1x1 convolution is also removed.
#
# IMPORTANT:
# Start Block 4 from block3_output.
#
# block3_output = 28 x 28 x 96
# ============================================================

block4_branch = block3_output

# Main branch convolution
block4_branch = Conv2D(
    128,
    (3, 3),
    activation="relu",
    padding="same",
    name="block4_conv_128"
)(block4_branch)

block4_branch = BatchNormalization(
    name="block4_bn_128"
)(block4_branch)


# ------------------------------------------------------------
# REMOVED 1x1 CONVOLUTION #1
# ------------------------------------------------------------
# block4_branch = Conv2D(
#     64,
#     (1, 1),
#     activation="relu",
#     padding="same"
# )(block4_branch)


block4_output = Conv2D(
    160,
    (3, 3),
    activation="relu",
    padding="same",
    name="block4_conv_160"
)(block4_branch)

block4_output = BatchNormalization(
    name="block4_bn_160"
)(block4_output)


# ============================================================
# SKIP CONNECTION
#
# block4_output : 28 x 28 x 160
# block3_output : 28 x 28 x 96
#
# Concatenation:
# 28 x 28 x (160 + 96)
# = 28 x 28 x 256
# ============================================================

x = Concatenate(
    axis=-1,
    name="skip_connection"
)([
    block4_output,
    block3_output
])


# Now downsample
x = MaxPooling2D(
    (2, 2),
    name="skip_pool"
)(x)


# ============================================================
# BLOCK 5 — MAIN BRANCH
#
# NO DWSC HERE
# ============================================================

x = Conv2D(
    192,
    (3, 3),
    activation="relu",
    padding="same",
    name="block5_conv_192"
)(x)

x = BatchNormalization(
    name="block5_bn_192"
)(x)


# ------------------------------------------------------------
# REMOVED 1x1 CONVOLUTION #2
# ------------------------------------------------------------
# x = Conv2D(
#     96,
#     (1, 1),
#     activation="relu",
#     padding="same"
# )(x)


x = Conv2D(
    224,
    (3, 3),
    activation="relu",
    padding="same",
    name="block5_conv_224"
)(x)

x = BatchNormalization(
    name="block5_bn_224"
)(x)


# ============================================================
# MAIN BRANCH FINAL POOLING
# ============================================================

main_branch_output = MaxPooling2D(
    (2, 2),
    name="main_final_pool"
)(x)

main_branch_output = BatchNormalization(
    name="main_final_bn"
)(main_branch_output)


# ============================================================
# SAM / PARALLEL BRANCH
#
# IMPORTANT:
# DWSC / DepthwiseConv2D IS KEPT HERE.
#
# This branch is NOT modified for Experiment 2.
# ============================================================

parallel_branch = DepthwiseConv2D(
    kernel_size=(5, 5),
    activation="relu",
    name="sam_dwsc_5x5_1"
)(block4_branch)

parallel_branch = Conv2D(
    64,
    (3, 3),
    padding="same",
    dilation_rate=2,
    name="sam_dilated_conv"
)(parallel_branch)

parallel_branch = BatchNormalization(
    name="sam_bn_1"
)(parallel_branch)

parallel_branch = ReLU(
    name="sam_relu"
)(parallel_branch)

parallel_branch = MaxPooling2D(
    (2, 2),
    name="sam_pool"
)(parallel_branch)

# ------------------------------------------------------------
# SECOND SAM DWSC — KEPT
# ------------------------------------------------------------

parallel_branch = DepthwiseConv2D(
    kernel_size=(5, 5),
    activation="relu",
    name="sam_dwsc_5x5_2"
)(parallel_branch)

parallel_branch = BatchNormalization(
    name="sam_bn_2"
)(parallel_branch)


# ============================================================
# GLOBAL AVERAGE POOLING
# ============================================================

main_branch_gap = GlobalAveragePooling2D(
    name="main_global_average_pool"
)(main_branch_output)

parallel_branch_gap = GlobalAveragePooling2D(
    name="sam_global_average_pool"
)(parallel_branch)


# ============================================================
# FUSION
# ============================================================

x = Concatenate(
    axis=-1,
    name="main_sam_fusion"
)([
    main_branch_gap,
    parallel_branch_gap
])


# ============================================================
# OUTPUT
# ============================================================

output_layer = Dense(
    4,
    activation="softmax",
    name="output"
)(x)


# ============================================================
# MODEL
# ============================================================

model = Model(
    inputs=input_layer,
    outputs=output_layer,
    name="Experiment_2_Main_DWSC_Removed_SAM_DWSC_Kept"
)


# ============================================================
# SUMMARY
# ============================================================

model.summary()
# Out:
# Model: "Experiment_2_Main_DWSC_Removed_SAM_DWSC_Kept"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 224, 224,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv         │ (None, 224, 224,  │        896 │ input[0][0]       │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_bn           │ (None, 224, 224,  │        128 │ block1_conv[0][0] │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_bn[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv         │ (None, 112, 112,  │     18,496 │ block1_pool[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_bn           │ (None, 112, 112,  │        256 │ block2_conv[0][0] │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_bn[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv         │ (None, 56, 56,    │     55,392 │ block2_pool[0][0] │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_bn           │ (None, 56, 56,    │        384 │ block3_conv[0][0] │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_bn[0][0]   │
# │ (MaxPooling2D)      │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv_128     │ (None, 28, 28,    │    110,720 │ block3_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn_128       │ (None, 28, 28,    │        512 │ block4_conv_128[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv_160     │ (None, 28, 28,    │    184,480 │ block4_bn_128[0]… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn_160       │ (None, 28, 28,    │        640 │ block4_conv_160[… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_connection     │ (None, 28, 28,    │          0 │ block4_bn_160[0]… │
# │ (Concatenate)       │ 256)              │            │ block3_pool[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_pool           │ (None, 14, 14,    │          0 │ skip_connection[… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sam_dwsc_5x5_1      │ (None, 24, 24,    │      3,328 │ block4_bn_128[0]… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv_192     │ (None, 14, 14,    │    442,560 │ skip_pool[0][0]   │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sam_dilated_conv    │ (None, 24, 24,    │     73,792 │ sam_dwsc_5x5_1[0… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_bn_192       │ (None, 14, 14,    │        768 │ block5_conv_192[… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sam_bn_1            │ (None, 24, 24,    │        256 │ sam_dilated_conv… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv_224     │ (None, 14, 14,    │    387,296 │ block5_bn_192[0]… │
# │ (Conv2D)            │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sam_relu (ReLU)     │ (None, 24, 24,    │          0 │ sam_bn_1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_bn_224       │ (None, 14, 14,    │        896 │ block5_conv_224[… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sam_pool            │ (None, 12, 12,    │          0 │ sam_relu[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_final_pool     │ (None, 7, 7, 224) │          0 │ block5_bn_224[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sam_dwsc_5x5_2      │ (None, 8, 8, 64)  │      1,664 │ sam_pool[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_final_bn       │ (None, 7, 7, 224) │        896 │ main_final_pool[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sam_bn_2            │ (None, 8, 8, 64)  │        256 │ sam_dwsc_5x5_2[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_global_averag… │ (None, 224)       │          0 │ main_final_bn[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sam_global_average… │ (None, 64)        │          0 │ sam_bn_2[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_sam_fusion     │ (None, 288)       │          0 │ main_global_aver… │
# │ (Concatenate)       │                   │            │ sam_global_avera… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 4)         │      1,156 │ main_sam_fusion[… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,284,772 (4.90 MB)
#  Trainable params: 1,282,276 (4.89 MB)
#  Non-trainable params: 2,496 (9.75 KB)

# %%
# Model diagram. If Graphviz is unavailable in a particular Colab runtime,
# the notebook continues without failing.
try:
    from tensorflow.keras.utils import plot_model
    from IPython.display import Image, display
    plot_model(model, to_file="convnet.png", show_shapes=True, show_layer_names=True)
    display(Image(filename="convnet.png"))
except Exception as e:
    print("Model plot skipped:", e)

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=0.0005),
    metrics=METRICS
)

# %%
def lr_schedule(epoch,learning_rate):
  if epoch <7:
    return learning_rate
  else:
    return 0.95*learning_rate

lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
# print("Length of train_dataset:", len(train_dataset))
# print("Length of valid_dataset:", len(valid_dataset))

# %%
callbacks = [
    ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True, verbose=1)#,
    # EarlyStopping(monitor="val_loss", patience=10, verbose=1, restore_best_weights=True)
]

# %%
# ============================================================
# FINAL CHECK + TRAINING
# ============================================================

output_classes = int(model.output_shape[-1])

print("=" * 70)
print("FINAL MODEL / DATA CHECK")
print("=" * 70)

print("Model output classes :", output_classes)
print("Train classes        :", train_generator.num_classes)
print("Validation classes   :", validation_generator.num_classes)
print("Test classes         :", test_generator.num_classes)

if output_classes != 4:
    raise ValueError(
        f"Model must have 4 outputs, but has {output_classes}."
    )

for name, generator in [
    ("train_generator", train_generator),
    ("validation_generator", validation_generator),
    ("test_generator", test_generator),
]:
    if generator.num_classes != 4:
        raise ValueError(
            f"{name} must contain 4 classes, "
            f"but contains {generator.num_classes}."
        )

# Check actual one-hot label shape before training
train_generator.reset()
x_batch, y_batch = next(train_generator)

print("\nBatch shape check:")
print("Images:", x_batch.shape)
print("Labels:", y_batch.shape)
print("Model :", model.output_shape)

if y_batch.shape[-1] != output_classes:
    raise ValueError(
        f"Target/output mismatch: targets have "
        f"{y_batch.shape[-1]} classes but model outputs "
        f"{output_classes}."
    )

train_generator.reset()

print("\nAll checks passed. Starting training...\n")

history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=35,
    callbacks=callbacks + [lr_scheduler],
    verbose=1
)
# Out:
# ======================================================================
# FINAL MODEL / DATA CHECK
# ======================================================================
# Model output classes : 4
# Train classes        : 4
# Validation classes   : 4
# Test classes         : 4
#
# Batch shape check:
# Images: (16, 224, 224, 3)
# Labels: (16, 4)
# Model : (None, 4)
#
# All checks passed. Starting training...
#
# Epoch 1/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.4616 - auc: 0.7225 - f1_score: 0.4616 - loss: 1.2122 - precision: 0.5851 - recall: 0.2870
# Epoch 1: val_accuracy improved from None to 0.22000, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 42s 558ms/step - accuracy: 0.5130 - auc: 0.7672 - f1_score: 0.5130 - loss: 1.1070 - precision: 0.6271 - recall: 0.3282 - val_accuracy: 0.2200 - val_auc: 0.7164 - val_f1_score: 0.2200 - val_loss: 2.0124 - val_precision: 0.2745 - val_recall: 0.2100 - learning_rate: 5.0000e-04
# Epoch 2/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6089 - auc: 0.8663 - f1_score: 0.6089 - loss: 0.8892 - precision: 0.7914 - recall: 0.3636
# Epoch 2: val_accuracy improved from 0.22000 to 0.42500, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - accuracy: 0.6598 - auc: 0.8868 - f1_score: 0.6598 - loss: 0.8129 - precision: 0.7692 - recall: 0.4663 - val_accuracy: 0.4250 - val_auc: 0.7758 - val_f1_score: 0.4250 - val_loss: 1.1899 - val_precision: 0.8431 - val_recall: 0.2150 - learning_rate: 5.0000e-04
# Epoch 3/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7248 - auc: 0.9270 - f1_score: 0.7248 - loss: 0.6649 - precision: 0.7983 - recall: 0.6228
# Epoch 3: val_accuracy improved from 0.42500 to 0.62500, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.7461 - auc: 0.9243 - f1_score: 0.7461 - loss: 0.6585 - precision: 0.8293 - recall: 0.6546 - val_accuracy: 0.6250 - val_auc: 0.8923 - val_f1_score: 0.6250 - val_loss: 0.8875 - val_precision: 0.8986 - val_recall: 0.3100 - learning_rate: 5.0000e-04
# Epoch 4/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7712 - auc: 0.9481 - f1_score: 0.7712 - loss: 0.5747 - precision: 0.8356 - recall: 0.6635
# Epoch 4: val_accuracy did not improve from 0.62500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.7807 - auc: 0.9424 - f1_score: 0.7807 - loss: 0.5684 - precision: 0.8361 - recall: 0.6874 - val_accuracy: 0.5800 - val_auc: 0.9133 - val_f1_score: 0.5800 - val_loss: 0.8624 - val_precision: 0.6774 - val_recall: 0.5250 - learning_rate: 5.0000e-04
# Epoch 5/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8767 - auc: 0.9753 - f1_score: 0.8767 - loss: 0.3795 - precision: 0.9087 - recall: 0.8216
# Epoch 5: val_accuracy improved from 0.62500 to 0.64500, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - accuracy: 0.8687 - auc: 0.9739 - f1_score: 0.8687 - loss: 0.3900 - precision: 0.8985 - recall: 0.8256 - val_accuracy: 0.6450 - val_auc: 0.9055 - val_f1_score: 0.6450 - val_loss: 0.8678 - val_precision: 0.7570 - val_recall: 0.4050 - learning_rate: 5.0000e-04
# Epoch 6/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9366 - auc: 0.9935 - f1_score: 0.9366 - loss: 0.2839 - precision: 0.9471 - recall: 0.8996
# Epoch 6: val_accuracy improved from 0.64500 to 0.66000, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.9447 - auc: 0.9947 - f1_score: 0.9447 - loss: 0.2383 - precision: 0.9564 - recall: 0.9102 - val_accuracy: 0.6600 - val_auc: 0.9472 - val_f1_score: 0.6600 - val_loss: 0.7900 - val_precision: 0.7733 - val_recall: 0.5800 - learning_rate: 5.0000e-04
# Epoch 7/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9389 - auc: 0.9938 - f1_score: 0.9389 - loss: 0.2047 - precision: 0.9652 - recall: 0.9242
# Epoch 7: val_accuracy improved from 0.66000 to 0.82500, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9413 - auc: 0.9898 - f1_score: 0.9413 - loss: 0.2209 - precision: 0.9638 - recall: 0.9206 - val_accuracy: 0.8250 - val_auc: 0.9513 - val_f1_score: 0.8250 - val_loss: 0.5598 - val_precision: 0.8750 - val_recall: 0.7700 - learning_rate: 5.0000e-04
# Epoch 8/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9058 - auc: 0.9931 - f1_score: 0.9058 - loss: 0.2115 - precision: 0.9302 - recall: 0.9004
# Epoch 8: val_accuracy improved from 0.82500 to 0.84500, saving model to best_model.keras
#
# Epoch 8: finished saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.9119 - auc: 0.9916 - f1_score: 0.9119 - loss: 0.2264 - precision: 0.9338 - recall: 0.9016 - val_accuracy: 0.8450 - val_auc: 0.9623 - val_f1_score: 0.8450 - val_loss: 0.4865 - val_precision: 0.8840 - val_recall: 0.8000 - learning_rate: 4.7500e-04
# Epoch 9/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9592 - auc: 0.9981 - f1_score: 0.9592 - loss: 0.1550 - precision: 0.9609 - recall: 0.9475
# Epoch 9: val_accuracy did not improve from 0.84500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.9585 - auc: 0.9981 - f1_score: 0.9585 - loss: 0.1333 - precision: 0.9633 - recall: 0.9516 - val_accuracy: 0.7650 - val_auc: 0.9523 - val_f1_score: 0.7650 - val_loss: 0.6207 - val_precision: 0.8187 - val_recall: 0.7000 - learning_rate: 4.5125e-04
# Epoch 10/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9858 - auc: 0.9998 - f1_score: 0.9858 - loss: 0.0813 - precision: 0.9880 - recall: 0.9855
# Epoch 10: val_accuracy improved from 0.84500 to 0.93000, saving model to best_model.keras
#
# Epoch 10: finished saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9879 - auc: 0.9999 - f1_score: 0.9879 - loss: 0.0719 - precision: 0.9896 - recall: 0.9862 - val_accuracy: 0.9300 - val_auc: 0.9783 - val_f1_score: 0.9300 - val_loss: 0.3389 - val_precision: 0.9485 - val_recall: 0.9200 - learning_rate: 4.2869e-04
# Epoch 11/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9901 - auc: 0.9998 - f1_score: 0.9901 - loss: 0.0570 - precision: 0.9910 - recall: 0.9889
# Epoch 11: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.9896 - auc: 0.9998 - f1_score: 0.9896 - loss: 0.0578 - precision: 0.9913 - recall: 0.9862 - val_accuracy: 0.8850 - val_auc: 0.9754 - val_f1_score: 0.8850 - val_loss: 0.4171 - val_precision: 0.9005 - val_recall: 0.8600 - learning_rate: 4.0725e-04
# Epoch 12/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9982 - auc: 1.0000 - f1_score: 0.9982 - loss: 0.0374 - precision: 1.0000 - recall: 0.9976
# Epoch 12: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.9965 - auc: 1.0000 - f1_score: 0.9965 - loss: 0.0399 - precision: 0.9983 - recall: 0.9948 - val_accuracy: 0.9050 - val_auc: 0.9762 - val_f1_score: 0.9050 - val_loss: 0.3585 - val_precision: 0.9128 - val_recall: 0.8900 - learning_rate: 3.8689e-04
# Epoch 13/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9894 - auc: 0.9994 - f1_score: 0.9894 - loss: 0.0595 - precision: 0.9894 - recall: 0.9894
# Epoch 13: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.9948 - auc: 0.9998 - f1_score: 0.9948 - loss: 0.0444 - precision: 0.9948 - recall: 0.9948 - val_accuracy: 0.8950 - val_auc: 0.9749 - val_f1_score: 0.8950 - val_loss: 0.3684 - val_precision: 0.9021 - val_recall: 0.8750 - learning_rate: 3.6755e-04
# Epoch 14/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9761 - auc: 0.9990 - f1_score: 0.9761 - loss: 0.0732 - precision: 0.9761 - recall: 0.9750
# Epoch 14: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.9741 - auc: 0.9986 - f1_score: 0.9741 - loss: 0.0837 - precision: 0.9740 - recall: 0.9724 - val_accuracy: 0.8700 - val_auc: 0.9706 - val_f1_score: 0.8700 - val_loss: 0.4526 - val_precision: 0.8788 - val_recall: 0.8700 - learning_rate: 3.4917e-04
# Epoch 15/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9614 - auc: 0.9973 - f1_score: 0.9614 - loss: 0.1149 - precision: 0.9633 - recall: 0.9545
# Epoch 15: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.9741 - auc: 0.9987 - f1_score: 0.9741 - loss: 0.1007 - precision: 0.9773 - recall: 0.9672 - val_accuracy: 0.8050 - val_auc: 0.9790 - val_f1_score: 0.8050 - val_loss: 0.5116 - val_precision: 0.8173 - val_recall: 0.8050 - learning_rate: 3.3171e-04
# Epoch 16/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9997 - auc: 1.0000 - f1_score: 0.9997 - loss: 0.0280 - precision: 0.9997 - recall: 0.9997
# Epoch 16: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.9983 - auc: 1.0000 - f1_score: 0.9983 - loss: 0.0296 - precision: 0.9983 - recall: 0.9983 - val_accuracy: 0.9100 - val_auc: 0.9783 - val_f1_score: 0.9100 - val_loss: 0.3669 - val_precision: 0.9082 - val_recall: 0.8900 - learning_rate: 3.1512e-04
# Epoch 17/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9944 - auc: 0.9999 - f1_score: 0.9944 - loss: 0.0425 - precision: 0.9944 - recall: 0.9944
# Epoch 17: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.9931 - auc: 0.9999 - f1_score: 0.9931 - loss: 0.0377 - precision: 0.9931 - recall: 0.9931 - val_accuracy: 0.9150 - val_auc: 0.9854 - val_f1_score: 0.9150 - val_loss: 0.3473 - val_precision: 0.9184 - val_recall: 0.9000 - learning_rate: 2.9937e-04
# Epoch 18/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9986 - auc: 1.0000 - f1_score: 0.9986 - loss: 0.0212 - precision: 0.9986 - recall: 0.9986
# Epoch 18: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.9965 - auc: 1.0000 - f1_score: 0.9965 - loss: 0.0249 - precision: 0.9965 - recall: 0.9965 - val_accuracy: 0.9200 - val_auc: 0.9822 - val_f1_score: 0.9200 - val_loss: 0.4925 - val_precision: 0.9239 - val_recall: 0.9100 - learning_rate: 2.8440e-04
# Epoch 19/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9979 - auc: 1.0000 - f1_score: 0.9979 - loss: 0.0233 - precision: 0.9979 - recall: 0.9979
# Epoch 19: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.9965 - auc: 0.9999 - f1_score: 0.9965 - loss: 0.0268 - precision: 0.9965 - recall: 0.9965 - val_accuracy: 0.9050 - val_auc: 0.9823 - val_f1_score: 0.9050 - val_loss: 0.4656 - val_precision: 0.9086 - val_recall: 0.8950 - learning_rate: 2.7018e-04
# Epoch 20/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9998 - auc: 1.0000 - f1_score: 0.9998 - loss: 0.0121 - precision: 0.9998 - recall: 0.9998
# Epoch 20: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.9965 - auc: 1.0000 - f1_score: 0.9965 - loss: 0.0212 - precision: 0.9965 - recall: 0.9965 - val_accuracy: 0.8000 - val_auc: 0.9581 - val_f1_score: 0.8000 - val_loss: 0.9076 - val_precision: 0.8201 - val_recall: 0.7750 - learning_rate: 2.5667e-04
# Epoch 21/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9722 - auc: 0.9986 - f1_score: 0.9722 - loss: 0.0766 - precision: 0.9730 - recall: 0.9721
# Epoch 21: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.9724 - auc: 0.9975 - f1_score: 0.9724 - loss: 0.0919 - precision: 0.9740 - recall: 0.9706 - val_accuracy: 0.8950 - val_auc: 0.9764 - val_f1_score: 0.8950 - val_loss: 0.4418 - val_precision: 0.9031 - val_recall: 0.8850 - learning_rate: 2.4384e-04
# Epoch 22/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9911 - auc: 0.9999 - f1_score: 0.9911 - loss: 0.0448 - precision: 0.9911 - recall: 0.9863
# Epoch 22: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.9948 - auc: 1.0000 - f1_score: 0.9948 - loss: 0.0393 - precision: 0.9948 - recall: 0.9879 - val_accuracy: 0.8250 - val_auc: 0.9712 - val_f1_score: 0.8250 - val_loss: 0.5138 - val_precision: 0.8241 - val_recall: 0.8200 - learning_rate: 2.3165e-04
# Epoch 23/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9946 - auc: 0.9993 - f1_score: 0.9946 - loss: 0.0443 - precision: 0.9946 - recall: 0.9894
# Epoch 23: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 0.9931 - auc: 0.9992 - f1_score: 0.9931 - loss: 0.0455 - precision: 0.9931 - recall: 0.9914 - val_accuracy: 0.8600 - val_auc: 0.9787 - val_f1_score: 0.8600 - val_loss: 0.4962 - val_precision: 0.8769 - val_recall: 0.8550 - learning_rate: 2.2006e-04
# Epoch 24/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9968 - auc: 0.9999 - f1_score: 0.9968 - loss: 0.0507 - precision: 0.9969 - recall: 0.9946
# Epoch 24: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.9948 - auc: 0.9998 - f1_score: 0.9948 - loss: 0.0425 - precision: 0.9965 - recall: 0.9914 - val_accuracy: 0.9000 - val_auc: 0.9843 - val_f1_score: 0.9000 - val_loss: 0.3890 - val_precision: 0.9045 - val_recall: 0.9000 - learning_rate: 2.0906e-04
# Epoch 25/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9940 - auc: 0.9998 - f1_score: 0.9940 - loss: 0.0363 - precision: 0.9960 - recall: 0.9940
# Epoch 25: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9914 - auc: 0.9998 - f1_score: 0.9914 - loss: 0.0414 - precision: 0.9931 - recall: 0.9914 - val_accuracy: 0.9150 - val_auc: 0.9862 - val_f1_score: 0.9150 - val_loss: 0.3174 - val_precision: 0.9137 - val_recall: 0.9000 - learning_rate: 1.9861e-04
# Epoch 26/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9983 - auc: 1.0000 - f1_score: 0.9983 - loss: 0.0186 - precision: 0.9983 - recall: 0.9983
# Epoch 26: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 0.9948 - auc: 1.0000 - f1_score: 0.9948 - loss: 0.0214 - precision: 0.9948 - recall: 0.9948 - val_accuracy: 0.8950 - val_auc: 0.9788 - val_f1_score: 0.8950 - val_loss: 0.3712 - val_precision: 0.9128 - val_recall: 0.8900 - learning_rate: 1.8868e-04
# Epoch 27/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9905 - auc: 1.0000 - f1_score: 0.9905 - loss: 0.0320 - precision: 0.9903 - recall: 0.9839
# Epoch 27: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.9965 - auc: 1.0000 - f1_score: 0.9965 - loss: 0.0234 - precision: 0.9965 - recall: 0.9948 - val_accuracy: 0.9250 - val_auc: 0.9836 - val_f1_score: 0.9250 - val_loss: 0.3187 - val_precision: 0.9239 - val_recall: 0.9100 - learning_rate: 1.7924e-04
# Epoch 28/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9988 - auc: 1.0000 - f1_score: 0.9988 - loss: 0.0163 - precision: 0.9988 - recall: 0.9988
# Epoch 28: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.9983 - auc: 1.0000 - f1_score: 0.9983 - loss: 0.0169 - precision: 0.9983 - recall: 0.9983 - val_accuracy: 0.9100 - val_auc: 0.9850 - val_f1_score: 0.9100 - val_loss: 0.3468 - val_precision: 0.9231 - val_recall: 0.9000 - learning_rate: 1.7028e-04
# Epoch 29/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0062 - precision: 1.0000 - recall: 1.0000
# Epoch 29: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0060 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9200 - val_auc: 0.9858 - val_f1_score: 0.9200 - val_loss: 0.3009 - val_precision: 0.9200 - val_recall: 0.9200 - learning_rate: 1.6177e-04
# Epoch 30/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0086 - precision: 1.0000 - recall: 0.9978
# Epoch 30: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0100 - precision: 1.0000 - recall: 0.9983 - val_accuracy: 0.8750 - val_auc: 0.9791 - val_f1_score: 0.8750 - val_loss: 0.3919 - val_precision: 0.8878 - val_recall: 0.8700 - learning_rate: 1.5368e-04
# Epoch 31/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0112 - precision: 1.0000 - recall: 1.0000
# Epoch 31: val_accuracy did not improve from 0.93000
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0115 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9150 - val_auc: 0.9841 - val_f1_score: 0.9150 - val_loss: 0.3588 - val_precision: 0.9146 - val_recall: 0.9100 - learning_rate: 1.4599e-04
# Epoch 32/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9974 - auc: 1.0000 - f1_score: 0.9974 - loss: 0.0157 - precision: 0.9974 - recall: 0.9974
# Epoch 32: val_accuracy improved from 0.93000 to 0.94500, saving model to best_model.keras
#
# Epoch 32: finished saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.9948 - auc: 1.0000 - f1_score: 0.9948 - loss: 0.0167 - precision: 0.9948 - recall: 0.9948 - val_accuracy: 0.9450 - val_auc: 0.9890 - val_f1_score: 0.9450 - val_loss: 0.2622 - val_precision: 0.9450 - val_recall: 0.9450 - learning_rate: 1.3869e-04
# Epoch 33/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9995 - auc: 1.0000 - f1_score: 0.9995 - loss: 0.0105 - precision: 0.9995 - recall: 0.9989
# Epoch 33: val_accuracy did not improve from 0.94500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 0.9983 - auc: 1.0000 - f1_score: 0.9983 - loss: 0.0125 - precision: 0.9983 - recall: 0.9965 - val_accuracy: 0.9400 - val_auc: 0.9859 - val_f1_score: 0.9400 - val_loss: 0.2838 - val_precision: 0.9447 - val_recall: 0.9400 - learning_rate: 1.3176e-04
# Epoch 34/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0059 - precision: 1.0000 - recall: 1.0000
# Epoch 34: val_accuracy did not improve from 0.94500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0088 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9400 - val_auc: 0.9873 - val_f1_score: 0.9400 - val_loss: 0.2651 - val_precision: 0.9447 - val_recall: 0.9400 - learning_rate: 1.2517e-04
# Epoch 35/35
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9993 - auc: 1.0000 - f1_score: 0.9993 - loss: 0.0053 - precision: 0.9993 - recall: 0.9993
# Epoch 35: val_accuracy did not improve from 0.94500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.9983 - auc: 1.0000 - f1_score: 0.9983 - loss: 0.0099 - precision: 0.9983 - recall: 0.9983 - val_accuracy: 0.9450 - val_auc: 0.9865 - val_f1_score: 0.9450 - val_loss: 0.3250 - val_precision: 0.9450 - val_recall: 0.9450 - learning_rate: 1.1891e-04

# %%
def Train_Val_Plot(acc, val_acc, loss, val_loss, auc, val_auc, precision, val_precision, f1, val_f1):

    fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(22, 5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    # Rescale the y-axis for accuracy, auc, precision, and f1
    rescale_factor = 0  # Adjust this factor to control the rescaling

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.set_ylim([0, 1.0])
    ax1.legend(['training', 'validation'])

    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.set_ylim([rescale_factor, 1.0])
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.set_ylim([rescale_factor, 1.0])
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.set_ylim([rescale_factor, 1.0])
    ax5.legend(['training', 'validation'])

    plt.show()

# Example usage:
Train_Val_Plot(history.history['accuracy'], history.history['val_accuracy'],
               history.history['loss'], history.history['val_loss']
               ,
               history.history['auc'], history.history['val_auc'],
               history.history['precision'], history.history['val_precision'],
               history.history['f1_score'], history.history['val_f1_score'])

# %%
model.evaluate(test_generator)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 230ms/step - accuracy: 0.9592 - auc: 0.9916 - f1_score: 0.9592 - loss: 0.1770 - precision: 0.9592 - recall: 0.9592
# [0.17697004973888397,
#  0.9591836929321289,
#  0.9591836929321289,
#  0.9591836929321289,
#  0.9916399717330933,
#  0.9591836333274841]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
# Load the test dataset
X_test, y_test = [], []
for i in range(len(test_generator)):
    batch_X, batch_y = test_generator[i]
    X_test.append(batch_X)
    y_test.append(batch_y)
X_test = np.concatenate(X_test)
y_test = np.concatenate(y_test)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Convert the one-hot encoded predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Convert the one-hot encoded true labels to class labels
y_true_classes = np.argmax(y_test, axis=1)

# Create a classification report
report = classification_report(y_true_classes, y_pred_classes)

print(report)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 215ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96        68
#            1       0.92      0.92      0.92        37
#            2       0.97      0.97      0.97        39
#            3       0.96      1.00      0.98        52
#
#     accuracy                           0.96       196
#    macro avg       0.96      0.96      0.96       196
# weighted avg       0.96      0.96      0.96       196

# %%
class_names = ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma']
# Create a confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plotting the Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# ============================================================
# EXPECTED RUNTIME
# - This notebook uses the TensorFlow/Keras version already provided by Colab.
# - It does NOT install tensorflow, keras, or tensorflow-addons.
# - The model architecture and training settings are otherwise preserved.
# - The original train + test + valid images are combined and re-split 60/20/20.
# ============================================================
